# %%
import pandas as pd

# %%
calgary_employment_sector_df = pd.read_csv("Calgary Job data.csv")
edmonton_employment_sector_df = pd.read_csv("Edmonton Job data.csv")
montreal_employment_sector_df = pd.read_csv("Montreal Job data.csv")
ottawa_employment_sector_df = pd.read_csv("Ottawa Job data.csv")
toronto_employment_sector_df = pd.read_csv("Toronto Job data.csv")
vancouver_employment_sector_df = pd.read_csv("Vancouver Job data.csv")
winnipeg_employment_sector_df = pd.read_csv("Winnipeg Job data.csv")

cities_employment_sector_df = [calgary_employment_sector_df, edmonton_employment_sector_df, montreal_employment_sector_df, ottawa_employment_sector_df, 
                        toronto_employment_sector_df, vancouver_employment_sector_df, winnipeg_employment_sector_df]
    
# calgary_employment_sector_df
# edmonton_employment_sector_df
# montreal_employment_sector_df
# ottawa_employment_sector_df
# toronto_employment_sector_df
# vancouver_employment_sector_df
# winnipeg_employment_sector_df

# %%
# cols_to_drop = calgary_employment_sector_df.columns[[1,2,4,6,7,8,9,10,12,13,14,15]]
# calgary_employment_sector_df.drop(cols_to_drop, axis=1, inplace=True)

# %%
# calgary_employment_sector_df

# %%
cleaned_city_employment_sector_dfs = []
for city in cities_employment_sector_df:
    # cols_to_drop = city.columns[[1,2,4,6,7,8,9,10,12,13,14,15]]
    cols_to_drop = city.columns[[1,2,4,6,7,8,9,10,12,13,14,15]]
    cityName = city.iloc[1,1].split(",")[0]
    city.drop(cols_to_drop, axis=1, inplace=True)
    city["city"] = cityName 
    
    cleaned_city_employment_sector_dfs.append(city)

# %%
for city in cities_employment_sector_df:
    city = city[["city", "REF_DATE", "Employment characteristics", "UOM", "VALUE"]]
    
    
calgary_employment_sector_df
# Out:
#     REF_DATE                         Employment characteristics  \
# 0       2024                                     Total employed
# 1       2024                             Goods-producing sector
# 2       2024             Agriculture [111-112, 1100, 1151-1152]
# 3       2024  Forestry, fishing, mining, quarrying, oil and ...
# 4       2024                                     Utilities [22]
# 5       2024                                  Construction [23]
# 6       2024                              Manufacturing [31-33]
# 7       2024                          Services-producing sector
# 8       2024             Wholesale and retail trade [41, 44-45]
# 9       2024             Transportation and warehousing [48-49]
# 10      2024  Finance, insurance, real estate, rental and le...
# 11      2024  Professional, scientific and technical service...
# 12      2024  Business, building and other support services ...
# 13      2024                          Educational services [61]
# ...

# %%
# calgary_employment_sector_df.to_csv('../employment_chart_data/csv_files/calgary-reduced.csv', index=False)
# for city in cities_employment_sector_df:
#     city.to_csv(f'../employment_chart_data/csv_files/{city}-reduced.csv', index=False)

# %%
# for city in cities_employment_sector_df:
#     print(city)

# %%
total_employed_df = pd.DataFrame([df.iloc[0] for df in cities_employment_sector_df])

# %%
total_employed_df
# Out:
#    REF_DATE Employment characteristics                   UOM   VALUE  \
# 0      2024             Total employed  Persons in thousands  1009.3
# 0      2024             Total employed  Persons in thousands   852.9
# 0      2024             Total employed  Persons in thousands  1098.8
# 0      2024             Total employed  Persons in thousands   836.3
# 0      2024             Total employed  Persons in thousands  3852.0
# 0      2024             Total employed  Persons in thousands   469.2
# 0      2024             Total employed  Persons in thousands   449.4
#
#                          city
# 0                     Calgary
# 0                    Edmonton
# 0                    Montréal
# 0                      Ottawa
# 0                     Toronto
# 0  Vancouver Island and Coast
# 0                    Winnipeg

# %%
total_employed_df.to_csv('../employment_chart_data/csv_files/total_employed.csv', index=False)

# %%
goods_producing_df = pd.DataFrame([df.iloc[1] for df in cities_employment_sector_df])
goods_producing_df
# Out:
#    REF_DATE Employment characteristics                   UOM  VALUE  \
# 1      2024     Goods-producing sector  Persons in thousands  218.1
# 1      2024     Goods-producing sector  Persons in thousands  174.2
# 1      2024     Goods-producing sector  Persons in thousands  156.9
# 1      2024     Goods-producing sector  Persons in thousands  116.1
# 1      2024     Goods-producing sector  Persons in thousands  611.8
# 1      2024     Goods-producing sector  Persons in thousands   71.3
# 1      2024     Goods-producing sector  Persons in thousands   76.2
#
#                          city
# 1                     Calgary
# 1                    Edmonton
# 1                    Montréal
# 1                      Ottawa
# 1                     Toronto
# 1  Vancouver Island and Coast
# 1                    Winnipeg

# %%
goods_producing_df.to_csv('../employment_chart_data/csv_files/goods_producing.csv', index=False)

# %%
agriculture_df = pd.DataFrame([df.iloc[2] for df in cities_employment_sector_df])
agriculture_df
# Out:
#    REF_DATE              Employment characteristics                   UOM  \
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
# 2      2024  Agriculture [111-112, 1100, 1151-1152]  Persons in thousands
#
#    VALUE                        city
# 2    4.1                     Calgary
# 2    2.3                    Edmonton
# 2    2.4                    Montréal
# 2    6.1                      Ottawa
# 2    4.4                     Toronto
# 2    3.5  Vancouver Island and Coast
# 2    NaN                    Winnipeg

# %%
agriculture_df.to_csv('../employment_chart_data/csv_files/agriculture_df.csv', index=False)

# %%
extracting_raw_materials_df = pd.DataFrame([df.iloc[3] for df in cities_employment_sector_df])
extracting_raw_materials_df
# Out:
#    REF_DATE                         Employment characteristics  \
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
# 3      2024  Forestry, fishing, mining, quarrying, oil and ...
#
#                     UOM  VALUE                        city
# 3  Persons in thousands   52.5                     Calgary
# 3  Persons in thousands   26.0                    Edmonton
# 3  Persons in thousands    1.6                    Montréal
# 3  Persons in thousands    2.1                      Ottawa
# 3  Persons in thousands    6.1                     Toronto
# 3  Persons in thousands    8.1  Vancouver Island and Coast
# ...

# %%
extracting_raw_materials_df.to_csv('../employment_chart_data/csv_files/extracting_raw_materials_df.csv', index=False)

# %%
utilities_df = pd.DataFrame([df.iloc[4] for df in cities_employment_sector_df])
utilities_df
# Out:
#    REF_DATE Employment characteristics                   UOM  VALUE  \
# 4      2024             Utilities [22]  Persons in thousands    9.9
# 4      2024             Utilities [22]  Persons in thousands    5.3
# 4      2024             Utilities [22]  Persons in thousands    5.8
# 4      2024             Utilities [22]  Persons in thousands    2.4
# 4      2024             Utilities [22]  Persons in thousands   23.3
# 4      2024             Utilities [22]  Persons in thousands    NaN
# 4      2024             Utilities [22]  Persons in thousands    3.5
#
#                          city
# 4                     Calgary
# 4                    Edmonton
# 4                    Montréal
# 4                      Ottawa
# 4                     Toronto
# 4  Vancouver Island and Coast
# 4                    Winnipeg

# %%
utilities_df.to_csv('../employment_chart_data/csv_files/utilities_df.csv', index=False)

# %%
construction_df = pd.DataFrame([df.iloc[5] for df in cities_employment_sector_df])
construction_df
# Out:
#    REF_DATE Employment characteristics                   UOM  VALUE  \
# 5      2024          Construction [23]  Persons in thousands   94.6
# 5      2024          Construction [23]  Persons in thousands   89.0
# 5      2024          Construction [23]  Persons in thousands   38.5
# 5      2024          Construction [23]  Persons in thousands   64.8
# 5      2024          Construction [23]  Persons in thousands  223.7
# 5      2024          Construction [23]  Persons in thousands   38.8
# 5      2024          Construction [23]  Persons in thousands   29.4
#
#                          city
# 5                     Calgary
# 5                    Edmonton
# 5                    Montréal
# 5                      Ottawa
# 5                     Toronto
# 5  Vancouver Island and Coast
# 5                    Winnipeg

# %%
manufacturing_df = pd.DataFrame([df.iloc[6] for df in cities_employment_sector_df])
manufacturing_df
# Out:
#    REF_DATE Employment characteristics                   UOM  VALUE  \
# 6      2024      Manufacturing [31-33]  Persons in thousands   57.0
# 6      2024      Manufacturing [31-33]  Persons in thousands   51.5
# 6      2024      Manufacturing [31-33]  Persons in thousands  108.6
# 6      2024      Manufacturing [31-33]  Persons in thousands   40.6
# 6      2024      Manufacturing [31-33]  Persons in thousands  354.2
# 6      2024      Manufacturing [31-33]  Persons in thousands   19.5
# 6      2024      Manufacturing [31-33]  Persons in thousands   41.4
#
#                          city
# 6                     Calgary
# 6                    Edmonton
# 6                    Montréal
# 6                      Ottawa
# 6                     Toronto
# 6  Vancouver Island and Coast
# 6                    Winnipeg

# %%
services_df = pd.DataFrame([df.iloc[7] for df in cities_employment_sector_df])
services_df
# Out:
#    REF_DATE Employment characteristics                   UOM   VALUE  \
# 7      2024  Services-producing sector  Persons in thousands   791.2
# 7      2024  Services-producing sector  Persons in thousands   678.7
# 7      2024  Services-producing sector  Persons in thousands   942.0
# 7      2024  Services-producing sector  Persons in thousands   720.2
# 7      2024  Services-producing sector  Persons in thousands  3240.2
# 7      2024  Services-producing sector  Persons in thousands   397.9
# 7      2024  Services-producing sector  Persons in thousands   373.2
#
#                          city
# 7                     Calgary
# 7                    Edmonton
# 7                    Montréal
# 7                      Ottawa
# 7                     Toronto
# 7  Vancouver Island and Coast
# 7                    Winnipeg

# %%
wholesale_and_retail_df = pd.DataFrame([df.iloc[8] for df in cities_employment_sector_df])
wholesale_and_retail_df
# Out:
#    REF_DATE              Employment characteristics                   UOM  \
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
# 8      2024  Wholesale and retail trade [41, 44-45]  Persons in thousands
#
#    VALUE                        city
# 8  131.6                     Calgary
# 8  136.2                    Edmonton
# 8  145.9                    Montréal
# 8  102.9                      Ottawa
# 8  534.4                     Toronto
# 8   61.9  Vancouver Island and Coast
# 8   63.0                    Winnipeg

# %%
transportation_and_warehousing_df = pd.DataFrame([df.iloc[9] for df in cities_employment_sector_df])
transportation_and_warehousing_df
# Out:
#    REF_DATE              Employment characteristics                   UOM  \
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
# 9      2024  Transportation and warehousing [48-49]  Persons in thousands
#
#    VALUE                        city
# 9   65.3                     Calgary
# 9   45.5                    Edmonton
# 9   62.9                    Montréal
# 9   32.8                      Ottawa
# 9  230.9                     Toronto
# 9   19.3  Vancouver Island and Coast
# 9   33.4                    Winnipeg

# %%
finance_insurance_real_estate_rental_and_leasing_df = pd.DataFrame([df.iloc[10] for df in cities_employment_sector_df])
finance_insurance_real_estate_rental_and_leasing_df
# Out:
#     REF_DATE                         Employment characteristics  \
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
# 10      2024  Finance, insurance, real estate, rental and le...
#
#                      UOM  VALUE                        city
# 10  Persons in thousands   62.9                     Calgary
# 10  Persons in thousands   46.8                    Edmonton
# 10  Persons in thousands   81.0                    Montréal
# 10  Persons in thousands   41.5                      Ottawa
# 10  Persons in thousands  456.0                     Toronto
# 10  Persons in thousands   22.1  Vancouver Island and Coast
# ...

# %%
finance_df.iloc[1,1]
# Out:
# 'Finance, insurance, real estate, rental and leasing [52-53]'

# %%
professional_scientific_and_technical_services_df = pd.DataFrame([df.iloc[11] for df in cities_employment_sector_df])
professional_scientific_and_technical_services_df
# Out:
#     REF_DATE                         Employment characteristics  \
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
# 11      2024  Professional, scientific and technical service...
#
#                      UOM  VALUE                        city
# 11  Persons in thousands  137.3                     Calgary
# 11  Persons in thousands   73.4                    Edmonton
# 11  Persons in thousands  148.9                    Montréal
# 11  Persons in thousands   89.4                      Ottawa
# 11  Persons in thousands  548.5                     Toronto
# 11  Persons in thousands   41.4  Vancouver Island and Coast
# ...

# %%
professional_scientific_and_technical_services_df.iloc[1,1]
# Out:
# 'Professional, scientific and technical services [54]'

# %%
business_building_and_other_support_services_df = pd.DataFrame([df.iloc[12] for df in cities_employment_sector_df])
business_building_and_other_support_services_df
# Out:
#     REF_DATE                         Employment characteristics  \
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
# 12      2024  Business, building and other support services ...
#
#                      UOM  VALUE                        city
# 12  Persons in thousands   35.1                     Calgary
# 12  Persons in thousands   28.8                    Edmonton
# 12  Persons in thousands   41.9                    Montréal
# 12  Persons in thousands   25.4                      Ottawa
# 12  Persons in thousands  140.5                     Toronto
# 12  Persons in thousands   15.6  Vancouver Island and Coast
# ...

# %%
educational_services_df = pd.DataFrame([df.iloc[13] for df in cities_employment_sector_df])
educational_services_df
# Out:
#     REF_DATE Employment characteristics                   UOM  VALUE  \
# 13      2024  Educational services [61]  Persons in thousands   61.3
# 13      2024  Educational services [61]  Persons in thousands   65.0
# 13      2024  Educational services [61]  Persons in thousands   88.8
# 13      2024  Educational services [61]  Persons in thousands   60.3
# 13      2024  Educational services [61]  Persons in thousands  264.5
# 13      2024  Educational services [61]  Persons in thousands   35.4
# 13      2024  Educational services [61]  Persons in thousands   42.0
#
#                           city
# 13                     Calgary
# 13                    Edmonton
# 13                    Montréal
# 13                      Ottawa
# 13                     Toronto
# 13  Vancouver Island and Coast
# 13                    Winnipeg

# %%
healthcare_and_social_assistance_df = pd.DataFrame([df.iloc[14] for df in cities_employment_sector_df])
healthcare_and_social_assistance_df
# Out:
#     REF_DATE              Employment characteristics                   UOM  \
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
# 14      2024  Health care and social assistance [62]  Persons in thousands
#
#     VALUE                        city
# 14  123.2                     Calgary
# 14  113.9                    Edmonton
# 14  156.0                    Montréal
# 14   95.0                      Ottawa
# 14  434.4                     Toronto
# 14   80.8  Vancouver Island and Coast
# 14   71.6                    Winnipeg

# %%
information_culture_and_recreation_df = pd.DataFrame([df.iloc[15] for df in cities_employment_sector_df])
information_culture_and_recreation_df
# Out:
#     REF_DATE                    Employment characteristics  \
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
# 15      2024  Information, culture and recreation [51, 71]
#
#                      UOM  VALUE                        city
# 15  Persons in thousands   41.9                     Calgary
# 15  Persons in thousands   29.5                    Edmonton
# 15  Persons in thousands   71.1                    Montréal
# 15  Persons in thousands   30.7                      Ottawa
# 15  Persons in thousands  175.8                     Toronto
# 15  Persons in thousands   23.5  Vancouver Island and Coast
# 15  Persons in thousands   17.5                    Winnipeg

# %%
accommodation_and_food_services_df = pd.DataFrame([df.iloc[16] for df in cities_employment_sector_df])
accommodation_and_food_services_df
# Out:
#     REF_DATE            Employment characteristics                   UOM  \
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
# 16      2024  Accommodation and food services [72]  Persons in thousands
#
#     VALUE                        city
# 16   60.2                     Calgary
# 16   47.8                    Edmonton
# 16   67.1                    Montréal
# 16   46.4                      Ottawa
# 16  180.8                     Toronto
# 16   34.5  Vancouver Island and Coast
# 16   23.9                    Winnipeg

# %%
other_services_df = pd.DataFrame([df.iloc[17] for df in cities_employment_sector_df])
other_services_df
# Out:
#     REF_DATE                         Employment characteristics  \
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
# 17      2024  Other services (except public administration) ...
#
#                      UOM  VALUE                        city
# 17  Persons in thousands   40.8                     Calgary
# 17  Persons in thousands   32.1                    Edmonton
# 17  Persons in thousands   36.5                    Montréal
# 17  Persons in thousands   24.7                      Ottawa
# 17  Persons in thousands  134.5                     Toronto
# 17  Persons in thousands   18.5  Vancouver Island and Coast
# ...

# %%
public_admin_services_df = pd.DataFrame([df.iloc[18] for df in cities_employment_sector_df])
public_admin_services_df
# Out:
#     REF_DATE  Employment characteristics                   UOM  VALUE  \
# 18      2024  Public administration [91]  Persons in thousands   31.7
# 18      2024  Public administration [91]  Persons in thousands   59.8
# 18      2024  Public administration [91]  Persons in thousands   42.0
# 18      2024  Public administration [91]  Persons in thousands  171.0
# 18      2024  Public administration [91]  Persons in thousands  140.0
# 18      2024  Public administration [91]  Persons in thousands   45.0
# 18      2024  Public administration [91]  Persons in thousands   28.7
#
#                           city
# 18                     Calgary
# 18                    Edmonton
# 18                    Montréal
# 18                      Ottawa
# 18                     Toronto
# 18  Vancouver Island and Coast
# 18                    Winnipeg

# %%
cities_df.to_csv("Output/city_amenities_data.csv")
print("✅ Amenities and location data saved as 'city_amenities_data.csv'")
